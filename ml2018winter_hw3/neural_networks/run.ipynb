# %% [markdown]
# # Neural Networks
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **forward** and **backward** operations for different layers in neural networks
# - implement a simple neural networks for classification
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
digit_data = sio.loadmat('digit_data.mat')
X = digit_data['X']
y = digit_data['y']
_, num_cases = X.shape
train_num_cases = num_cases * 4 // 5
X = X.reshape((400, num_cases))
X = X.transpose()
# X has the shape of (number of samples, number of pixels)
train_data = X[:train_num_cases,:]
train_label = y[:, :train_num_cases]
test_data = X[train_num_cases:, :]
test_label = y[:, train_num_cases:]
weights = {}
weights['fully1_weight'] = np.random.randn(400, 25) / 400
weights['fully1_bias'] = np.random.rand(25, 1) 
weights['fully2_weight'] = np.random.randn(25, 10) / 25
weights['fully2_bias'] = np.random.rand(10, 1)

# %% [markdown]
# ## Training

# %%
# training setting
weight_inc = {}
for name in ('fully1_weight', 'fully1_bias', 'fully2_weight', 'fully2_bias'):
    weight_inc[name] = np.zeros(weights[name].shape)
batch_size = 100
max_epoch = 10
momW = 0.9
wc = 0.0005
learning_rate = 0.1

# Training iterations
from get_new_weight_inc import get_new_weight_inc
from feedforward_backprop import feedforward_backprop

for epoch in range(max_epoch):
    for i in range(math.ceil(train_num_cases/batch_size)):
        data = train_data[i * batch_size:min((i + 1) * batch_size, train_num_cases), :]
        label = train_label[:, i * batch_size:min((i + 1) * batch_size, train_num_cases)]
        # The feedforward and backpropgation processes
        loss, accuracy, gradients = feedforward_backprop(data, label, weights)
        print('{:3}.{:2} loss:{:.3}, accuracy:{}'.format(epoch + 1, i + 1, loss, accuracy))
        # Updating weights
        for name in ('fully1_weight', 'fully1_bias', 'fully2_weight', 'fully2_bias'):
            weight_inc[name] = get_new_weight_inc(weight_inc[name], weights[name], momW, wc, learning_rate, gradients[name + '_grad'])
            weights[name] += weight_inc[name]
# Out:
#   1. 1 loss:2.31, accuracy:0.17
#   1. 2 loss:2.34, accuracy:0.11
#   1. 3 loss:2.28, accuracy:0.13
#   1. 4 loss:2.31, accuracy:0.1
#   1. 5 loss:2.28, accuracy:0.11
#   1. 6 loss:2.29, accuracy:0.14
#   1. 7 loss:2.27, accuracy:0.1
#   1. 8 loss:2.25, accuracy:0.21
#   1. 9 loss:2.23, accuracy:0.19
#   1.10 loss:2.23, accuracy:0.28
#   1.11 loss:2.18, accuracy:0.33
#   1.12 loss:2.16, accuracy:0.28
#   1.13 loss:2.16, accuracy:0.29
#   1.14 loss:2.16, accuracy:0.26
#   1.15 loss:2.04, accuracy:0.31
#   1.16 loss:1.96, accuracy:0.56
#   1.17 loss:1.94, accuracy:0.47
#   1.18 loss:1.86, accuracy:0.49
#   1.19 loss:1.88, accuracy:0.41
#   1.20 loss:1.64, accuracy:0.58
#   1.21 loss:1.57, accuracy:0.54
#   1.22 loss:1.47, accuracy:0.53
#   1.23 loss:1.4, accuracy:0.62
#   1.24 loss:1.21, accuracy:0.65
#   1.25 loss:1.21, accuracy:0.71
#   1.26 loss:1.07, accuracy:0.74
#   1.27 loss:1.13, accuracy:0.68
#   1.28 loss:0.922, accuracy:0.76
#   1.29 loss:0.864, accuracy:0.79
#   1.30 loss:0.901, accuracy:0.7
#   1.31 loss:0.822, accuracy:0.79
#   1.32 loss:0.793, accuracy:0.74
#   1.33 loss:0.699, accuracy:0.75
#   1.34 loss:0.726, accuracy:0.78
#   1.35 loss:0.872, accuracy:0.72
#   1.36 loss:0.687, accuracy:0.82
#   1.37 loss:0.593, accuracy:0.81
#   1.38 loss:0.626, accuracy:0.77
#   1.39 loss:0.584, accuracy:0.82
#   1.40 loss:0.725, accuracy:0.8
#   2. 1 loss:0.581, accuracy:0.76
#   2. 2 loss:0.608, accuracy:0.82
#   2. 3 loss:0.485, accuracy:0.87
#   2. 4 loss:0.703, accuracy:0.79
#   2. 5 loss:0.693, accuracy:0.76
#   2. 6 loss:0.377, accuracy:0.9
#   2. 7 loss:0.626, accuracy:0.8
#   2. 8 loss:0.432, accuracy:0.84
#   2. 9 loss:0.381, accuracy:0.88
#   2.10 loss:0.615, accuracy:0.82
#   2.11 loss:0.526, accuracy:0.81
#   2.12 loss:0.885, accuracy:0.79
#   2.13 loss:0.659, accuracy:0.75
#   2.14 loss:0.675, accuracy:0.77
#   2.15 loss:0.31, accuracy:0.9
#   2.16 loss:0.579, accuracy:0.79
#   2.17 loss:0.655, accuracy:0.75
#   2.18 loss:0.619, accuracy:0.84
#   2.19 loss:0.503, accuracy:0.83
#   2.20 loss:0.405, accuracy:0.87
#   2.21 loss:0.588, accuracy:0.83
#   2.22 loss:0.663, accuracy:0.86
#   2.23 loss:0.431, accuracy:0.84
#   2.24 loss:0.416, accuracy:0.84
#   2.25 loss:0.323, accuracy:0.93
#   2.26 loss:0.392, accuracy:0.89
#   2.27 loss:0.783, accuracy:0.76
#   2.28 loss:0.513, accuracy:0.88
#   2.29 loss:0.416, accuracy:0.87
#   2.30 loss:0.366, accuracy:0.85
#   2.31 loss:0.436, accuracy:0.87
#   2.32 loss:0.473, accuracy:0.84
#   2.33 loss:0.57, accuracy:0.84
#   2.34 loss:0.503, accuracy:0.85
#   2.35 loss:0.534, accuracy:0.85
#   2.36 loss:0.411, accuracy:0.89
#   2.37 loss:0.3, accuracy:0.92
#   2.38 loss:0.45, accuracy:0.86
#   2.39 loss:0.341, accuracy:0.91
#   2.40 loss:0.475, accuracy:0.89
#   3. 1 loss:0.298, accuracy:0.92
#   3. 2 loss:0.414, accuracy:0.88
#   3. 3 loss:0.238, accuracy:0.93
#   3. 4 loss:0.516, accuracy:0.9
#   3. 5 loss:0.383, accuracy:0.9
#   3. 6 loss:0.239, accuracy:0.95
#   3. 7 loss:0.405, accuracy:0.9
#   3. 8 loss:0.236, accuracy:0.93
#   3. 9 loss:0.185, accuracy:0.94
#   3.10 loss:0.342, accuracy:0.91
#   3.11 loss:0.297, accuracy:0.91
#   3.12 loss:0.491, accuracy:0.86
#   3.13 loss:0.423, accuracy:0.85
#   3.14 loss:0.464, accuracy:0.84
#   3.15 loss:0.21, accuracy:0.92
#   3.16 loss:0.246, accuracy:0.93
#   3.17 loss:0.318, accuracy:0.9
#   3.18 loss:0.505, accuracy:0.87
#   3.19 loss:0.456, accuracy:0.81
#   3.20 loss:0.32, accuracy:0.9
#   3.21 loss:0.329, accuracy:0.9
#   3.22 loss:0.349, accuracy:0.9
#   3.23 loss:0.325, accuracy:0.92
#   3.24 loss:0.292, accuracy:0.92
#   3.25 loss:0.253, accuracy:0.93
#   3.26 loss:0.299, accuracy:0.9
#   3.27 loss:0.454, accuracy:0.84
#   3.28 loss:0.317, accuracy:0.91
#   3.29 loss:0.3, accuracy:0.92
#   3.30 loss:0.246, accuracy:0.92
#   3.31 loss:0.328, accuracy:0.89
#   3.32 loss:0.284, accuracy:0.89
#   3.33 loss:0.315, accuracy:0.9
#   3.34 loss:0.325, accuracy:0.92
#   3.35 loss:0.378, accuracy:0.91
#   3.36 loss:0.3, accuracy:0.94
#   3.37 loss:0.258, accuracy:0.9
#   3.38 loss:0.275, accuracy:0.93
#   3.39 loss:0.291, accuracy:0.93
#   3.40 loss:0.446, accuracy:0.91
#   4. 1 loss:0.213, accuracy:0.94
#   4. 2 loss:0.29, accuracy:0.91
#   4. 3 loss:0.189, accuracy:0.94
#   4. 4 loss:0.366, accuracy:0.92
#   4. 5 loss:0.296, accuracy:0.92
#   4. 6 loss:0.165, accuracy:0.98
#   4. 7 loss:0.382, accuracy:0.89
#   4. 8 loss:0.214, accuracy:0.97
#   4. 9 loss:0.184, accuracy:0.96
#   4.10 loss:0.32, accuracy:0.91
#   4.11 loss:0.221, accuracy:0.92
#   4.12 loss:0.383, accuracy:0.9
#   4.13 loss:0.344, accuracy:0.86
#   4.14 loss:0.397, accuracy:0.88
#   4.15 loss:0.159, accuracy:0.94
#   4.16 loss:0.237, accuracy:0.95
#   4.17 loss:0.24, accuracy:0.92
#   4.18 loss:0.399, accuracy:0.89
#   4.19 loss:0.386, accuracy:0.86
#   4.20 loss:0.289, accuracy:0.93
#   4.21 loss:0.292, accuracy:0.91
#   4.22 loss:0.267, accuracy:0.91
#   4.23 loss:0.273, accuracy:0.92
#   4.24 loss:0.228, accuracy:0.93
#   4.25 loss:0.154, accuracy:0.96
#   4.26 loss:0.224, accuracy:0.93
#   4.27 loss:0.319, accuracy:0.92
#   4.28 loss:0.256, accuracy:0.92
#   4.29 loss:0.269, accuracy:0.94
#   4.30 loss:0.23, accuracy:0.92
#   4.31 loss:0.241, accuracy:0.9
#   4.32 loss:0.204, accuracy:0.94
#   4.33 loss:0.251, accuracy:0.94
#   4.34 loss:0.266, accuracy:0.93
#   4.35 loss:0.339, accuracy:0.92
#   4.36 loss:0.287, accuracy:0.94
#   4.37 loss:0.226, accuracy:0.92
#   4.38 loss:0.232, accuracy:0.94
#   4.39 loss:0.247, accuracy:0.95
#   4.40 loss:0.383, accuracy:0.92
#   5. 1 loss:0.175, accuracy:0.95
#   5. 2 loss:0.261, accuracy:0.9
#   5. 3 loss:0.167, accuracy:0.94
#   5. 4 loss:0.305, accuracy:0.94
#   5. 5 loss:0.26, accuracy:0.93
#   5. 6 loss:0.12, accuracy:0.98
#   5. 7 loss:0.298, accuracy:0.92
#   5. 8 loss:0.154, accuracy:0.97
#   5. 9 loss:0.158, accuracy:0.97
#   5.10 loss:0.302, accuracy:0.9
#   5.11 loss:0.186, accuracy:0.93
#   5.12 loss:0.321, accuracy:0.92
#   5.13 loss:0.295, accuracy:0.88
#   5.14 loss:0.352, accuracy:0.9
#   5.15 loss:0.122, accuracy:0.98
#   5.16 loss:0.24, accuracy:0.95
#   5.17 loss:0.202, accuracy:0.94
#   5.18 loss:0.335, accuracy:0.93
#   5.19 loss:0.334, accuracy:0.9
#   5.20 loss:0.248, accuracy:0.93
#   5.21 loss:0.235, accuracy:0.92
#   5.22 loss:0.224, accuracy:0.92
#   5.23 loss:0.245, accuracy:0.94
#   5.24 loss:0.215, accuracy:0.95
#   5.25 loss:0.135, accuracy:0.96
#   5.26 loss:0.166, accuracy:0.95
#   5.27 loss:0.236, accuracy:0.95
#   5.28 loss:0.203, accuracy:0.95
#   5.29 loss:0.23, accuracy:0.94
#   5.30 loss:0.21, accuracy:0.93
#   5.31 loss:0.202, accuracy:0.93
#   5.32 loss:0.166, accuracy:0.97
#   5.33 loss:0.262, accuracy:0.94
#   5.34 loss:0.254, accuracy:0.94
#   5.35 loss:0.322, accuracy:0.91
#   5.36 loss:0.235, accuracy:0.95
#   5.37 loss:0.215, accuracy:0.93
#   5.38 loss:0.213, accuracy:0.95
#   5.39 loss:0.218, accuracy:0.94
#   5.40 loss:0.333, accuracy:0.93
#   6. 1 loss:0.142, accuracy:0.96
#   6. 2 loss:0.244, accuracy:0.93
#   6. 3 loss:0.156, accuracy:0.94
#   6. 4 loss:0.259, accuracy:0.95
#   6. 5 loss:0.248, accuracy:0.94
#   6. 6 loss:0.118, accuracy:0.98
#   6. 7 loss:0.254, accuracy:0.92
#   6. 8 loss:0.114, accuracy:0.97
#   6. 9 loss:0.137, accuracy:0.96
#   6.10 loss:0.242, accuracy:0.92
#   6.11 loss:0.161, accuracy:0.94
#   6.12 loss:0.276, accuracy:0.94
#   6.13 loss:0.254, accuracy:0.9
#   6.14 loss:0.331, accuracy:0.92
#   6.15 loss:0.104, accuracy:0.98
#   6.16 loss:0.218, accuracy:0.94
#   6.17 loss:0.164, accuracy:0.94
#   6.18 loss:0.28, accuracy:0.95
#   6.19 loss:0.293, accuracy:0.91
#   6.20 loss:0.183, accuracy:0.94
#   6.21 loss:0.184, accuracy:0.94
#   6.22 loss:0.194, accuracy:0.93
#   6.23 loss:0.21, accuracy:0.97
#   6.24 loss:0.207, accuracy:0.93
#   6.25 loss:0.14, accuracy:0.95
#   6.26 loss:0.153, accuracy:0.95
#   6.27 loss:0.208, accuracy:0.92
#   6.28 loss:0.189, accuracy:0.95
#   6.29 loss:0.191, accuracy:0.95
#   6.30 loss:0.161, accuracy:0.97
#   6.31 loss:0.172, accuracy:0.95
#   6.32 loss:0.136, accuracy:0.97
#   6.33 loss:0.262, accuracy:0.92
#   6.34 loss:0.26, accuracy:0.93
#   6.35 loss:0.306, accuracy:0.9
#   6.36 loss:0.188, accuracy:0.96
#   6.37 loss:0.178, accuracy:0.94
#   6.38 loss:0.178, accuracy:0.96
#   6.39 loss:0.191, accuracy:0.94
#   6.40 loss:0.291, accuracy:0.92
#   7. 1 loss:0.11, accuracy:0.97
#   7. 2 loss:0.206, accuracy:0.94
#   7. 3 loss:0.131, accuracy:0.94
#   7. 4 loss:0.223, accuracy:0.95
#   7. 5 loss:0.221, accuracy:0.94
#   7. 6 loss:0.118, accuracy:0.97
#   7. 7 loss:0.227, accuracy:0.93
#   7. 8 loss:0.0993, accuracy:0.97
#   7. 9 loss:0.121, accuracy:0.97
#   7.10 loss:0.178, accuracy:0.94
#   7.11 loss:0.124, accuracy:0.94
#   7.12 loss:0.22, accuracy:0.95
#   7.13 loss:0.214, accuracy:0.91
#   7.14 loss:0.305, accuracy:0.91
#   7.15 loss:0.0882, accuracy:0.98
#   7.16 loss:0.168, accuracy:0.94
#   7.17 loss:0.121, accuracy:0.94
#   7.18 loss:0.254, accuracy:0.95
#   7.19 loss:0.275, accuracy:0.92
#   7.20 loss:0.138, accuracy:0.95
#   7.21 loss:0.163, accuracy:0.95
#   7.22 loss:0.164, accuracy:0.93
#   7.23 loss:0.184, accuracy:0.96
#   7.24 loss:0.182, accuracy:0.95
#   7.25 loss:0.12, accuracy:0.95
#   7.26 loss:0.15, accuracy:0.95
#   7.27 loss:0.218, accuracy:0.92
#   7.28 loss:0.166, accuracy:0.96
#   7.29 loss:0.155, accuracy:0.95
#   7.30 loss:0.132, accuracy:0.96
#   7.31 loss:0.156, accuracy:0.96
#   7.32 loss:0.128, accuracy:0.97
#   7.33 loss:0.234, accuracy:0.95
#   7.34 loss:0.217, accuracy:0.93
#   7.35 loss:0.263, accuracy:0.92
#   7.36 loss:0.17, accuracy:0.96
#   7.37 loss:0.145, accuracy:0.96
#   7.38 loss:0.147, accuracy:0.97
#   7.39 loss:0.173, accuracy:0.95
#   7.40 loss:0.263, accuracy:0.93
#   8. 1 loss:0.0931, accuracy:0.97
#   8. 2 loss:0.175, accuracy:0.94
#   8. 3 loss:0.111, accuracy:0.96
#   8. 4 loss:0.19, accuracy:0.95
#   8. 5 loss:0.194, accuracy:0.94
#   8. 6 loss:0.102, accuracy:0.98
#   8. 7 loss:0.194, accuracy:0.94
#   8. 8 loss:0.0876, accuracy:0.98
#   8. 9 loss:0.0994, accuracy:0.97
#   8.10 loss:0.127, accuracy:0.95
#   8.11 loss:0.112, accuracy:0.97
#   8.12 loss:0.201, accuracy:0.96
#   8.13 loss:0.186, accuracy:0.93
#   8.14 loss:0.258, accuracy:0.92
#   8.15 loss:0.0702, accuracy:1.0
#   8.16 loss:0.136, accuracy:0.96
#   8.17 loss:0.109, accuracy:0.96
#   8.18 loss:0.236, accuracy:0.94
#   8.19 loss:0.264, accuracy:0.94
#   8.20 loss:0.123, accuracy:0.97
#   8.21 loss:0.15, accuracy:0.96
#   8.22 loss:0.134, accuracy:0.93
#   8.23 loss:0.158, accuracy:0.96
#   8.24 loss:0.164, accuracy:0.95
#   8.25 loss:0.115, accuracy:0.96
#   8.26 loss:0.138, accuracy:0.96
#   8.27 loss:0.219, accuracy:0.93
#   8.28 loss:0.146, accuracy:0.97
#   8.29 loss:0.131, accuracy:0.97
#   8.30 loss:0.12, accuracy:0.96
#   8.31 loss:0.142, accuracy:0.96
#   8.32 loss:0.119, accuracy:0.97
#   8.33 loss:0.213, accuracy:0.95
#   8.34 loss:0.186, accuracy:0.94
#   8.35 loss:0.227, accuracy:0.94
#   8.36 loss:0.152, accuracy:0.96
#   8.37 loss:0.133, accuracy:0.97
#   8.38 loss:0.116, accuracy:0.98
#   8.39 loss:0.168, accuracy:0.97
#   8.40 loss:0.239, accuracy:0.92
#   9. 1 loss:0.0742, accuracy:0.99
#   9. 2 loss:0.151, accuracy:0.96
#   9. 3 loss:0.0878, accuracy:0.98
#   9. 4 loss:0.168, accuracy:0.96
#   9. 5 loss:0.177, accuracy:0.96
#   9. 6 loss:0.0826, accuracy:0.99
#   9. 7 loss:0.165, accuracy:0.94
#   9. 8 loss:0.0766, accuracy:0.98
#   9. 9 loss:0.0894, accuracy:0.97
#   9.10 loss:0.113, accuracy:0.95
#   9.11 loss:0.102, accuracy:0.97
#   9.12 loss:0.186, accuracy:0.97
#   9.13 loss:0.172, accuracy:0.93
#   9.14 loss:0.223, accuracy:0.93
#   9.15 loss:0.0615, accuracy:1.0
#   9.16 loss:0.112, accuracy:0.97
#   9.17 loss:0.104, accuracy:0.97
#   9.18 loss:0.22, accuracy:0.95
#   9.19 loss:0.244, accuracy:0.94
#   9.20 loss:0.123, accuracy:0.97
#   9.21 loss:0.14, accuracy:0.96
#   9.22 loss:0.113, accuracy:0.96
#   9.23 loss:0.136, accuracy:0.97
#   9.24 loss:0.14, accuracy:0.95
#   9.25 loss:0.0999, accuracy:0.96
#   9.26 loss:0.129, accuracy:0.96
#   9.27 loss:0.184, accuracy:0.95
#   9.28 loss:0.126, accuracy:0.98
#   9.29 loss:0.125, accuracy:0.97
#   9.30 loss:0.114, accuracy:0.97
#   9.31 loss:0.123, accuracy:0.96
#   9.32 loss:0.102, accuracy:0.97
#   9.33 loss:0.182, accuracy:0.97
#   9.34 loss:0.174, accuracy:0.95
#   9.35 loss:0.199, accuracy:0.97
#   9.36 loss:0.139, accuracy:0.96
#   9.37 loss:0.12, accuracy:0.97
#   9.38 loss:0.0998, accuracy:0.98
#   9.39 loss:0.161, accuracy:0.97
#   9.40 loss:0.206, accuracy:0.93
#  10. 1 loss:0.0599, accuracy:1.0
#  10. 2 loss:0.137, accuracy:0.97
#  10. 3 loss:0.0714, accuracy:0.98
#  10. 4 loss:0.153, accuracy:0.97
#  10. 5 loss:0.163, accuracy:0.96
#  10. 6 loss:0.0721, accuracy:0.99
#  10. 7 loss:0.148, accuracy:0.96
#  10. 8 loss:0.07, accuracy:0.98
#  10. 9 loss:0.0869, accuracy:0.99
#  10.10 loss:0.113, accuracy:0.95
#  10.11 loss:0.0932, accuracy:0.97
#  10.12 loss:0.164, accuracy:0.97
#  10.13 loss:0.153, accuracy:0.94
#  10.14 loss:0.197, accuracy:0.95
#  10.15 loss:0.055, accuracy:1.0
#  10.16 loss:0.101, accuracy:0.96
#  10.17 loss:0.0951, accuracy:0.97
#  10.18 loss:0.203, accuracy:0.94
#  10.19 loss:0.206, accuracy:0.96
#  10.20 loss:0.113, accuracy:0.96
#  10.21 loss:0.129, accuracy:0.96
#  10.22 loss:0.0977, accuracy:0.96
#  10.23 loss:0.117, accuracy:0.97
#  10.24 loss:0.12, accuracy:0.96
#  10.25 loss:0.0892, accuracy:0.96
#  10.26 loss:0.12, accuracy:0.97
#  10.27 loss:0.161, accuracy:0.96
#  10.28 loss:0.108, accuracy:0.98
#  10.29 loss:0.115, accuracy:0.98
#  10.30 loss:0.102, accuracy:0.98
#  10.31 loss:0.107, accuracy:0.96
#  10.32 loss:0.0897, accuracy:0.99
#  10.33 loss:0.162, accuracy:0.97
#  10.34 loss:0.161, accuracy:0.96
#  10.35 loss:0.193, accuracy:0.98
#  10.36 loss:0.119, accuracy:0.96
#  10.37 loss:0.103, accuracy:0.97
#  10.38 loss:0.0873, accuracy:0.99
#  10.39 loss:0.147, accuracy:0.97
#  10.40 loss:0.184, accuracy:0.95

# %% [markdown]
# ## Testing

# %%
# TODO
loss, accuracy, _ = feedforward_backprop(test_data, test_label, weights)
print('loss:{:.3}, accuracy:{}'.format(loss, accuracy))
# Out:
# loss:0.264, accuracy:0.921
